# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/DSData/master/happiness_score_dataset.csv')
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.shape
# Out:
# (158, 12)

# %% [markdown]
# So, here we can see there are 158 rows and 12 columns.
#
# Happiness score is our label(target label) and rest of them are features.

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %% [markdown]
# There are three types of data are here.Object,int and float type data.
#
# Happiness Score is float type. So our target variable is integer type.

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df.columns.to_list()
# Out:
# ['Country',
#  'Region',
#  'Happiness Rank',
#  'Happiness Score',
#  'Standard Error',
#  'Economy (GDP per Capita)',
#  'Family',
#  'Health (Life Expectancy)',
#  'Freedom',
#  'Trust (Government Corruption)',
#  'Generosity',
#  'Dystopia Residual']

# %%
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %% [markdown]
# So here we can say that there is no null value in any column.

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# From heatmap we can see also that there are no null values are here.

# %%
for i in df.columns:
    print(df[i].value_counts)
    print("\n")
# Out:
# <bound method IndexOpsMixin.value_counts of 0      Switzerland
# 1          Iceland
# 2          Denmark
# 3           Norway
# 4           Canada
#           ...
# 153         Rwanda
# 154          Benin
# 155          Syria
# 156        Burundi
# 157           Togo
# Name: Country, Length: 158, dtype: object>
#
#
# <bound method IndexOpsMixin.value_counts of 0                       Western Europe
# 1                       Western Europe
# 2                       Western Europe
# 3                       Western Europe
# 4                        North America
#                     ...
# 153                 Sub-Saharan Africa
# 154                 Sub-Saharan Africa
# 155    Middle East and Northern Africa
# 156                 Sub-Saharan Africa
# 157                 Sub-Saharan Africa
# Name: Region, Length: 158, dtype: object>
#
#
# <bound method IndexOpsMixin.value_counts of 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 153    154
# 154    155
# ...

# %%
df["Happiness Score"].unique()
# Out:
# array([7.587, 7.561, 7.527, 7.522, 7.427, 7.406, 7.378, 7.364, 7.286,
#        7.284, 7.278, 7.226, 7.2  , 7.187, 7.119, 6.983, 6.946, 6.94 ,
#        6.937, 6.901, 6.867, 6.853, 6.81 , 6.798, 6.786, 6.75 , 6.67 ,
#        6.611, 6.575, 6.574, 6.505, 6.485, 6.477, 6.455, 6.411, 6.329,
#        6.302, 6.298, 6.295, 6.269, 6.168, 6.13 , 6.123, 6.003, 5.995,
#        5.987, 5.984, 5.975, 5.96 , 5.948, 5.89 , 5.889, 5.878, 5.855,
#        5.848, 5.833, 5.828, 5.824, 5.813, 5.791, 5.77 , 5.759, 5.754,
#        5.716, 5.709, 5.695, 5.689, 5.605, 5.589, 5.548, 5.477, 5.474,
#        5.429, 5.399, 5.36 , 5.332, 5.286, 5.268, 5.253, 5.212, 5.194,
#        5.192, 5.14 , 5.129, 5.124, 5.123, 5.102, 5.098, 5.073, 5.057,
#        5.013, 5.007, 4.971, 4.959, 4.949, 4.898, 4.885, 4.876, 4.874,
#        4.867, 4.857, 4.839, 4.8  , 4.788, 4.786, 4.739, 4.715, 4.694,
#        4.686, 4.681, 4.677, 4.642, 4.633, 4.61 , 4.571, 4.565, 4.55 ,
# ...

# %%
df["Happiness Score"].nunique()
# Out:
# 157

# %% [markdown]
# So Out of 158 rows, there are 157 unique value.
#
# By this analysis, we can say that this is a regression problem not a classification problem.

# %%
df.nunique().to_frame('No.of unique values')
# Out:
#                                No.of unique values
# Country                                        158
# Region                                          10
# Happiness Rank                                 157
# Happiness Score                                157
# Standard Error                                 153
# Economy (GDP per Capita)                       158
# Family                                         158
# Health (Life Expectancy)                       157
# Freedom                                        158
# Trust (Government Corruption)                  157
# Generosity                                     158
# Dystopia Residual                              158

# %%
These are the unique value for almost each of the column. We can drop country column

# %%
#separating categorical and numerical column 
categorical_col=[]
for i in df.dtypes.index:  
    if df.dtypes[i]=="object":
        categorical_col.append(i)
print('categorical columns are',categorical_col)
print("\n")
numerical_col=[]
for i in df.dtypes.index:
    if df.dtypes[i]!="object":
        numerical_col.append(i)
print('Numerical columns are:',numerical_col)
# Out:
# categorical columns are ['Country', 'Region']
#
#
# Numerical columns are: ['Happiness Rank', 'Happiness Score', 'Standard Error', 'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)', 'Generosity', 'Dystopia Residual']

# %% [markdown]
# From here we can see that there are two columns which is having datatypes are object type.
#
# rest of the columns are numerical type.
#
# So we divide these into two parts, 1. Categorical Data 2.Numerical data.

# %% [markdown]
# Here we can see that the country and region has no significant role with the happiness score, so we are going to drop these columns.
#
# Happieness rank is also the byproduct of the other factor and also has no impact on the target variable. so we can drop this column also.

# %%
df.drop(['Country','Region','Happiness Rank'],axis=1,inplace=True)

# %%
df
# Out:
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# 1              7.561         0.04884                   1.30232  1.40223
# 2              7.527         0.03328                   1.32548  1.36058
# 3              7.522         0.03880                   1.45900  1.33095
# 4              7.427         0.03553                   1.32629  1.32261
# ..               ...             ...                       ...      ...
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# ...

# %%
df.describe()
# Out:
#        Happiness Score  Standard Error  Economy (GDP per Capita)      Family  \
# count       158.000000      158.000000                158.000000  158.000000
# mean          5.375734        0.047885                  0.846137    0.991046
# std           1.145010        0.017146                  0.403121    0.272369
# min           2.839000        0.018480                  0.000000    0.000000
# 25%           4.526000        0.037268                  0.545808    0.856823
# 50%           5.232500        0.043940                  0.910245    1.029510
# 75%           6.243750        0.052300                  1.158448    1.214405
# max           7.587000        0.136930                  1.690420    1.402230
#
#        Health (Life Expectancy)     Freedom  Trust (Government Corruption)  \
# count                158.000000  158.000000                     158.000000
# mean                   0.630259    0.428615                       0.143422
# ...

# %% [markdown]
# From this we can conclude these points:-
#
# 1.It shows the data for only numerical columns.
#
# 2.The no. of counts to each columns are same. so no data is missing from here.
#
# 3.The columns(Happiness score, Standard error,Trust,Generosity,Dystopia Residual) is having mean value are more than 50%. So these columnns will be right skewed.
#
# 4.In some columns we can see that there are big difference between 75% and 100% value for many columns(For eg. Generosity,Dystopia Residual etc.).From here we can say that there will be some outliers will also be there.

# %% [markdown]
# # Data Visualization

# %%
plt.figure(figsize=(22,15))
sns.heatmap(df.describe(),annot=True,fmt='0.2f',linecolor='red',linewidth=0.3)
plt.xlabel('figure',fontsize=10)
plt.yticks('Features',fontsize=10)
plt.title('Descriptice graph',fontsize=10)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\matplotlib\axis.py in convert_units(self, x)
#    1505         try:
# -> 1506             ret = self.converter.convert(x, self.units, self)
#    1507         except Exception as e:
#
# ~\anaconda3\lib\site-packages\matplotlib\category.py in convert(value, unit, axis)
#      48         if unit is None:
# ---> 49             raise ValueError(
#      50                 'Missing category information for StrCategoryConverter; '
#
# ValueError: Missing category information for StrCategoryConverter; this might be caused by unintendedly mixing categorical and numeric data
#
# The above exception was the direct cause of the following exception:
#
# ConversionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19304\4234101286.py in <module>
# ...

# %%
sns.lmplot(x='Happiness Score',y='Economy (GDP per Capita)',data=df,palette='colorblind')

# %% [markdown]
# Positive correlation between Happiness score and economy.

# %%
sns.lmplot(x='Family',y='Happiness Score',data=df,palette='colorblind')

# %% [markdown]
# We can see here that family has a positive correlation with happiness score.

# %%
sns.lmplot(x='Freedom',y='Happiness Score',data=df,palette='colorblind')

# %% [markdown]
# I cant see any relation between freedom and happiness score. The curve is totally scattered.

# %%
sns.lmplot(x='Trust (Government Corruption)',y='Happiness Score',data=df,palette='colorblind')

# %% [markdown]
# The country which is having low corruption will be having Happiness score.

# %%
sns.lmplot(x='Happiness Score',y='Generosity',data=df,palette='colorblind')

# %%
Slightly positive corelation between happiness score and generosity

# %%
sns.lmplot(x='Happiness Score',y='Dystopia Residual',data=df,palette='colorblind')

# %% [markdown]
# From These graphs onr thing we can say that there are positive corelation between happiness score and other features but not in the perfect way.
# data is quite scattered from the best fit line.

# %%
plt.figure(figsize=(30,35))
p=1
for i in df:
    if p<=15:
        plt.subplot(5,5,p)
        sns.regplot(x='Happiness Score',y=i,data=df,color='red')
        plt.xlabel('Happiness Score')
        plt.ylabel(i)
        plt.title('Regression plot in between Features and label')
        p+=1
plt.show()

# %% [markdown]
# From these curves we can say that except(Standard error,happiness rank),all others are having positive corelation with the happiness score.

# %%
plt.figure(figsize=(30,35))
p=1
for i in df:
    if p<=15:
        plt.subplot(5,5,p)
        sns.scatterplot(x='Happiness Score',y=i,data=df,color='red')
        plt.xlabel('Happiness Score')
        plt.ylabel(i)
        plt.title('Regression plot in between Features and label')
        p+=1
plt.show()

# %% [markdown]
# Scatterplot is also giving the same result as lmplot and regression plot.

# %%
sns.pairplot(data=df, palette='dark2')

# %%
plt.figure(figsize=(15,10))
sns.lineplot(data=df )
plt.xlabel('Happiness Score')
plt.title('General trend of all features')
# Out:
# Text(0.5, 1.0, 'General trend of all features')

# %% [markdown]
# Now we will find out the outliers in the features.

# %%
plt.figure(figsize=(20,18))
p=1
for i in df:
    if p<=15:
        plt.subplot(3,4,p)
        sns.boxplot(df[i],palette='Set2_r')
        plt.xlabel(i)
        p+=1
plt.show()

# %% [markdown]
# From these plots we can see that there are outliers present in standard error,family,Trust(Government corruption),Generosity and Dystopia residual.
#
# So first of all we have to remove these otliers by using z score method.

# %%
from scipy.stats import zscore

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
outliers_features=df[['Standard Error','Family','Trust (Government Corruption)','Generosity','Dystopia Residual']]
z=np.abs(zscore(outliers_features))
z
# Out:
#      Standard Error    Family  Trust (Government Corruption)  Generosity  \
# 0          0.805926  1.320281                       2.309652    0.471040
# 1          0.055889  1.514458                       0.016480    1.575856
# 2          0.854487  1.361054                       2.842774    0.824293
# 3          0.531526  1.251922                       1.852081    0.868638
# 4          0.722845  1.221204                       1.555725    1.748563
# ..              ...       ...                            ...         ...
# 153        0.774917  0.800520                       3.413922    0.087228
# 154        0.662582  2.346860                       0.529210    0.433117
# 155        0.132534  1.901086                       0.381419    1.856891
# 156        2.263962  2.118467                       0.357715    0.316950
# 157        1.134182  3.134725                       0.301803    0.558153
#
#      Dystopia Residual
# 0             0.758258
# 1             1.092857
# ...

# %%
np.where(z>3)
# Out:
# (array([ 27,  40,  64, 115, 128, 147, 153, 155, 157], dtype=int64),
#  array([2, 0, 0, 0, 3, 1, 2, 4, 1], dtype=int64))

# %%
z.iloc[40,0]
# Out:
# 3.5727739331415806

# %%
df1=df[(z<3).all(axis=1)]

# %%
df1.shape
# Out:
# (149, 12)

# %%
df1.shape[0]
# Out:
# 149

# %%
df.shape[0]
# Out:
# 158

# %%
print('Percentage loss of data',((df.shape[0]-df1.shape[0])/df.shape[0])*100)
# Out:
# Percentage loss of data 5.69620253164557

# %% [markdown]
# We can afford this percentage of data loss.

# %%
df=df1

# %%
df
# Out:
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# 1              7.561         0.04884                   1.30232  1.40223
# 2              7.527         0.03328                   1.32548  1.36058
# 3              7.522         0.03880                   1.45900  1.33095
# 4              7.427         0.03553                   1.32629  1.32261
# ..               ...             ...                       ...      ...
# 150            3.655         0.05141                   0.46534  0.77115
# 151            3.587         0.04324                   0.25812  0.85188
# 152            3.575         0.03084                   0.31982  0.30285
# 154            3.340         0.03656                   0.28665  0.35386
# 156            2.905         0.08658                   0.01530  0.41587
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# ...

# %% [markdown]
# Now we will check this with IQR method.

# %%
Q1=outliers_features.quantile(0.25)
Q3=outliers_features.quantile(0.75)
IQR=Q3-Q1
df2=df[~((df<(Q1-1.5*IQR))|(df>(Q3+1.5*IQR))).any(axis=1)]

# %%
df2.shape
# Out:
# (126, 10)

# %%
df2.shape[0]
# Out:
# 126

# %%
df.shape[0]
# Out:
# 149

# %%
print('Percentage of data loss',((df.shape[0]-df2.shape[0])/df.shape[0])*100)
# Out:
# Percentage of data loss 15.436241610738255

# %% [markdown]
# By this method we say that there are 15% loss of data. We can't afford this loss of data.

# %% [markdown]
# # Now We will check the distribution of data.

# %%
plt.figure(figsize=(20,25))
p=1
for column in df:
    if p<=20:
        plt.subplot(4,3,p)
        sns.distplot(df[column],color='b')
        plt.xlabel(column,fontsize=20)
        p+=1
plt.show()

# %% [markdown]
# From these curves we can say that almost all of the data is normally distributed except some column.
#
# Now we will check skewness in this data.

# %%
df.skew()
# Out:
# Happiness Score                  0.169740
# Standard Error                   1.243048
# Economy (GDP per Capita)        -0.390657
# Family                          -0.811340
# Health (Life Expectancy)        -0.747711
# Freedom                         -0.400867
# Trust (Government Corruption)    1.272530
# Generosity                       0.654710
# Dystopia Residual               -0.021144
# dtype: float64

# %% [markdown]
# So here we can see that standard error,family,health(life expectancy),trust(Government corruption) and Generosity have high skewness.
#
# So we will eliminate first skewness in these columns.

# %%
df['Standard Error']=np.cbrt(df['Standard Error'])

# %%
df.skew()
# Out:
# Happiness Score                  0.169740
# Standard Error                   0.528395
# Economy (GDP per Capita)        -0.390657
# Family                          -0.811340
# Health (Life Expectancy)        -0.747711
# Freedom                         -0.400867
# Trust (Government Corruption)    1.272530
# Generosity                       0.654710
# Dystopia Residual               -0.021144
# dtype: float64

# %%
df['Standard Error']=np.sqrt(df['Standard Error'])

# %%
df.skew()
# Out:
# Happiness Score                  0.169740
# Standard Error                   0.330734
# Economy (GDP per Capita)        -0.390657
# Family                          -0.811340
# Health (Life Expectancy)        -0.747711
# Freedom                         -0.400867
# Trust (Government Corruption)    1.272530
# Generosity                       0.654710
# Dystopia Residual               -0.021144
# dtype: float64

# %%
df['Trust (Government Corruption)']=np.cbrt(df['Trust (Government Corruption)'])

# %%
df.skew()
# Out:
# Happiness Score                  0.169740
# Standard Error                   0.330734
# Economy (GDP per Capita)        -0.390657
# Family                          -0.811340
# Health (Life Expectancy)        -0.747711
# Freedom                         -0.400867
# Trust (Government Corruption)   -0.064568
# Generosity                       0.654710
# Dystopia Residual               -0.021144
# dtype: float64

# %%
df['Generosity']=np.sqrt(df['Generosity'])
df.skew()
# Out:
# Happiness Score                  0.169740
# Standard Error                   0.330734
# Economy (GDP per Capita)        -0.390657
# Family                          -0.811340
# Health (Life Expectancy)        -0.747711
# Freedom                         -0.400867
# Trust (Government Corruption)   -0.064568
# Generosity                      -0.285799
# Dystopia Residual               -0.021144
# dtype: float64

# %%
plt.figure(figsize=(20,25))
p=1
for column in df:
    if p<=20:
        plt.subplot(4,3,p)
        sns.distplot(df[column],color='b')
        plt.xlabel(column,fontsize=20)
        p+=1
plt.show()

# %% [markdown]
# From these methods we remove skewness from the columns standard error, trust and generosity.
#
# Now we will check corelation between target variables and features.

# %%
cor=df.corr()
cor
# Out:
#                                Happiness Score  Standard Error  \
# Happiness Score                       1.000000       -0.237951
# Standard Error                       -0.237951        1.000000
# Economy (GDP per Capita)              0.773577       -0.242205
# Family                                0.720868       -0.126450
# Health (Life Expectancy)              0.729191       -0.338747
# Freedom                               0.585066       -0.205694
# Trust (Government Corruption)         0.394775       -0.097660
# Generosity                            0.223529       -0.118531
# Dystopia Residual                     0.528334        0.024886
#
#                                Economy (GDP per Capita)    Family  \
# Happiness Score                                0.773577  0.720868
# Standard Error                                -0.242205 -0.126450
# Economy (GDP per Capita)                       1.000000  0.628589
# Family                                         0.628589  1.000000
# ...

# %%
plt.figure(figsize=(22,18))
sns.heatmap(df.corr(),annot=True,linecolor='red',fmt='0.2f')
plt.xlabel('figure',fontsize=12)
plt.ylabel('feature_name',fontsize=12)
plt.title('Correlation between figure and feature name')
plt.show()

# %%
cor['Happiness Score'].sort_values(ascending=False)
# Out:
# Happiness Score                  1.000000
# Economy (GDP per Capita)         0.773577
# Health (Life Expectancy)         0.729191
# Family                           0.720868
# Freedom                          0.585066
# Dystopia Residual                0.528334
# Trust (Government Corruption)    0.394775
# Generosity                       0.223529
# Standard Error                  -0.237951
# Name: Happiness Score, dtype: float64

# %% [markdown]
# We can observe the positive corelated between target variable and features except standard error.

# %% [markdown]
# Visualizing the corelation between label and features using barplot

# %%
plt.figure(figsize=(22,18))
df.corr()['Happiness Score'].sort_values(ascending=False).drop(['Happiness Score']).plot(kind='bar',color='m')
plt.xlabel('feature',fontsize=12)
plt.ylabel('Target',fontsize=12)
plt.title('Barplot between features and target')
plt.show()

# %% [markdown]
# From the above bar plot we can notice that the standard error is having negative corelation with target variable.

# %% [markdown]
# Now we will separate feature and label.

# %%
x=df.drop('Happiness Score',axis=1)
y=df["Happiness Score"]

# %%
x
# Out:
#      Standard Error  Economy (GDP per Capita)   Family  \
# 0          0.569482                   1.39651  1.34951
# 1          0.604592                   1.30232  1.40223
# 2          0.567149                   1.32548  1.36058
# 3          0.581842                   1.45900  1.33095
# 4          0.573367                   1.32629  1.32261
# ..              ...                       ...      ...
# 150        0.609782                   0.46534  0.77115
# 151        0.592444                   0.25812  0.85188
# 152        0.559997                   0.31982  0.30285
# 154        0.576104                   0.28665  0.35386
# 156        0.665124                   0.01530  0.41587
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                       0.748756
# 1                     0.94784  0.62877                       0.521036
# 2                     0.87464  0.64938                       0.784910
# ...

# %%
y
# Out:
# 0      7.587
# 1      7.561
# 2      7.527
# 3      7.522
# 4      7.427
#        ...
# 150    3.655
# 151    3.587
# 152    3.575
# 154    3.340
# 156    2.905
# Name: Happiness Score, Length: 149, dtype: float64

# %% [markdown]
# # Feature using standard scaler

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#      Standard Error  Economy (GDP per Capita)    Family  \
# 0         -0.915072                  1.381916  1.357879
# 1          0.313664                  1.138324  1.567882
# 2         -0.996731                  1.198220  1.401974
# 3         -0.482514                  1.543526  1.283947
# 4         -0.779130                  1.200315  1.250726
# ..              ...                       ...       ...
# 144        0.495287                 -1.026255 -0.945943
# 145       -0.111473                 -1.562163 -0.624365
# 146       -1.247029                 -1.402596 -2.811354
# 147       -0.683330                 -1.488379 -2.608163
# 148        2.432099                 -2.190139 -2.361154
#
#      Health (Life Expectancy)   Freedom  Trust (Government Corruption)  \
# 0                    1.235390  1.583704                       1.886835
# 1                    1.261541  1.338953                       0.279412
# 2                    0.962900  1.476027                       2.142033
# ...

# %% [markdown]
# We use the standard scaler method to overcome the issue of biasness.

# %% [markdown]
# # Variance Inflation Factor

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif=pd.DataFrame()
vif["VIF Values"]=[variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif["Features"]=x.columns
vif
# Out:
#    VIF Values                       Features
# 0    1.154269                 Standard Error
# 1    4.144256       Economy (GDP per Capita)
# 2    1.945921                         Family
# 3    3.398385       Health (Life Expectancy)
# 4    1.959932                        Freedom
# 5    1.387120  Trust (Government Corruption)
# 6    1.346484                     Generosity
# 7    1.036922              Dystopia Residual

# %% [markdown]
# So here we can see that vif value for all the columns is less than 5. so there are no multicollinearity with respect to the other columns.

# %% [markdown]
# # Modelling

# %%
df.shape
# Out:
# (149, 9)

# %%
y.value_counts()
# Out:
# 5.192    2
# 7.587    1
# 4.739    1
# 4.874    1
# 4.867    1
#         ..
# 5.889    1
# 5.878    1
# 5.855    1
# 5.848    1
# 2.905    1
# Name: Happiness Score, Length: 148, dtype: int64

# %%
Here we can see that data is almost balanced. It is a regression problem.

# %%
#finding the best random state
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# # Creating train test split

# %%
Maxacc=0
Maxrs=0
for i in range(1,150):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.25,random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    pred=lr.predict(x_test)
    accu=r2_score(y_test,pred)
    if accu>=Maxacc:
        Maxacc=accu
        Maxrs=i
print('Best r2 Score:',Maxacc,'With random state',Maxrs)
# Out:
# Best r2 Score: 0.9994190116935662 With random state 77

# %% [markdown]
# So the best accuracy score is 99% at random state 77.

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=Maxrs)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import Lasso,Ridge

# %%
LR=LinearRegression()
LR.fit(x_train,y_train)
pred_LR=LR.predict(x_test)
pred_train=LR.predict(x_train)
print('r2 score of test data',r2_score(y_test,pred_LR))
print('r2 score of train data',r2_score(y_train,pred_train)*100)
print('Mean absolute error',mean_absolute_error(y_test,pred_LR))
print('mean squared error',mean_squared_error(y_test,pred_LR))
print('Root mean squared error',np.sqrt(mean_squared_error(y_test,pred_LR)))
# Out:
# r2 score of test data 0.9994190116935662
# r2 score of train data 99.75513885484902
# Mean absolute error 0.021166518103894413
# mean squared error 0.0007018983992806276
# Root mean squared error 0.026493365193584365

# %% [markdown]
# From here we can see that there are very less error and high r2 score for this model.

# %% [markdown]
# Now we will confirm this by scatter plot.

# %%
plt.figure(figsize=(15,10))
plt.scatter(x=pred_LR,y=y_test,color='r')
plt.plot(pred_LR,pred_LR,color='b')
plt.xlabel('Actual',fontsize=14)
plt.ylabel('Predicted',fontsize=14)
plt.title('Linear Regression')
plt.show()

# %%
RFR=RandomForestRegressor()
RFR.fit(x_train,y_train)
RFR_pred=RFR.predict(x_test)
RFR_train=RFR.predict(x_train)
print('r2 score of test data',r2_score(y_test,RFR_pred))
print('r2 score of train data',r2_score(y_train,RFR_train)*100)
print('Mean absolute error',mean_absolute_error(y_test,RFR_pred))
print('mean squared error',mean_squared_error(y_test,RFR_pred))
print('Root mean squared error',np.sqrt(mean_squared_error(y_test,RFR_pred)))
# Out:
# r2 score of test data 0.8681066230699108
# r2 score of train data 98.80724513338748
# Mean absolute error 0.3089360526315794
# mean squared error 0.15934184753421055
# Root mean squared error 0.3991764616484927

# %%
gbr=GradientBoostingRegressor()
gbr.fit(x_train,y_train)
pred_gbr=gbr.predict(x_test)
train_gbr=gbr.predict(x_train)
print('r2 score of test data',r2_score(y_test,pred_gbr))
print('r2 score of train data',r2_score(y_train,train_gbr)*100)
print('Mean absolute error',mean_absolute_error(y_test,pred_gbr))
print('mean squared error',mean_squared_error(y_test,pred_gbr))
print('Root mean squared error',np.sqrt(mean_squared_error(y_test,pred_gbr)))
# Out:
# r2 score of test data 0.9177014439265243
# r2 score of train data 99.95674069101656
# Mean absolute error 0.2423135034412472
# mean squared error 0.09942579589190728
# Root mean squared error 0.3153185625552471

# %%
lasso=Lasso()
lasso.fit(x_train,y_train)
las_pred=lasso.predict(x_test)
las_train=lasso.predict(x_train)
print('r2 score of test data',r2_score(y_test,las_pred))
print('r2 score of train data',r2_score(y_train,las_train)*100)
print('Mean absolute error',mean_absolute_error(y_test,las_pred))
print('mean squared error',mean_squared_error(y_test,las_pred))
print('Root mean squared error',np.sqrt(mean_squared_error(y_test,las_pred)))
# Out:
# r2 score of test data -0.11560026823455938
# r2 score of train data 0.0
# Mean absolute error 0.9864438122332855
# mean squared error 1.3477690236438418
# Root mean squared error 1.1609345475279138

# %%
ridge=Ridge()
ridge.fit(x_train,y_train)
rid_pred=ridge.predict(x_test)
rid_train=ridge.predict(x_train)
print('r2 score of test data',r2_score(y_test,rid_pred))
print('r2 score of train data',r2_score(y_train,rid_train)*100)
print('Mean absolute error',mean_absolute_error(y_test,rid_pred))
print('mean squared error',mean_squared_error(y_test,rid_pred))
print('Root mean squared error',np.sqrt(mean_squared_error(y_test,rid_pred)))
# Out:
# r2 score of test data 0.999390266110825
# r2 score of train data 99.75177234681874
# Mean absolute error 0.021461516706074896
# mean squared error 0.0007366262557433311
# Root mean squared error 0.027140859524770602

# %%
dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
dtr_pred=dtr.predict(x_test)
dtr_train=dtr.predict(x_train)
print('r2 score of test data',r2_score(y_test,dtr_pred))
print('r2 score of train data',r2_score(y_train,dtr_train)*100)
print('Mean absolute error',mean_absolute_error(y_test,dtr_pred))
print('mean squared error',mean_squared_error(y_test,dtr_pred))
print('Root mean squared error',np.sqrt(mean_squared_error(y_test,dtr_pred)))
# Out:
# r2 score of test data 0.821675792620862
# r2 score of train data 100.0
# Mean absolute error 0.37744736842105253
# mean squared error 0.215435447368421
# Root mean squared error 0.4641502422367363

# %%
from sklearn.tree import ExtraTreeRegressor
etr=ExtraTreeRegressor()
etr.fit(x_train,y_train)
etr_pred=etr.predict(x_test)
etr_train=etr.predict(x_train)
print('r2 score of test data',r2_score(y_test,etr_pred))
print('r2 score of train data',r2_score(y_train,etr_train)*100)
print('Mean absolute error',mean_absolute_error(y_test,etr_pred))
print('mean squared error',mean_squared_error(y_test,etr_pred))
print('Root mean squared error',np.sqrt(mean_squared_error(y_test,etr_pred)))
# Out:
# r2 score of test data 0.7013251024395716
# r2 score of train data 100.0
# Mean absolute error 0.5013947368421052
# mean squared error 0.36083244736842107
# Root mean squared error 0.6006933055798284

# %% [markdown]
# Now we are going to validate the data by using cross validation score.

# %%
from sklearn.model_selection import cross_val_score

# %%
score=cross_val_score(LR,x,y)
print(score)
print(score.mean())
print('The difference between the r2 score and cross validation score is',(r2_score(y_test,pred_LR)-score.mean())*100)
# Out:
# [0.93137313 0.962305   0.89203204 0.8573257  0.98898421]
# 0.9264040159476414
# The difference between the r2 score and cross validation score is 7.301499574592474

# %%
score=cross_val_score(RFR,x,y)
print(score)
print(score.mean())
print('The difference between the r2 score and cross validation score is',(r2_score(y_test,RFR_pred)-score.mean())*100)
# Out:
# [-7.29384167 -1.16916942 -0.52074901 -2.266178   -6.46919504]
# -3.5438266299423278
# The difference between the r2 score and cross validation score is 441.1933253012238

# %%
score=cross_val_score(gbr,x,y)
print(score)
print(score.mean())
print('The difference between the r2 score and cross validation score is',(r2_score(y_test,pred_gbr)-score.mean())*100)
# Out:
# [-4.48002517  0.00628738 -0.55301119 -3.08821666 -3.99499984]
# -2.42199309475304
# The difference between the r2 score and cross validation score is 333.9694538679565

# %%
score=cross_val_score(dtr,x,y)
print(score)
print(score.mean())
print('The difference between the r2 score and cross validation score is',(r2_score(y_test,dtr_pred)-score.mean())*100)
# Out:
# [ -5.3300055   -7.16211983  -6.75789725 -10.88642547  -5.62306213]
# -7.151902035579646
# The difference between the r2 score and cross validation score is 795.7383125053971

# %%
score=cross_val_score(etr,x,y)
print(score)
print(score.mean())
print('The difference between the r2 score and cross validation score is',(r2_score(y_test,etr_pred)-score.mean())*100)
# Out:
# [ -6.63224249  -7.11030943  -8.10932341 -19.71038481  -5.51055801]
# -9.414563629286484
# The difference between the r2 score and cross validation score is 1011.5888731726055

# %%
score=cross_val_score(ridge,x,y)
print(score)
print(score.mean())
print('The difference between the r2 score and cross validation score is',(r2_score(y_test,rid_pred)-score.mean())*100)
# Out:
# [0.90715968 0.96343442 0.89236566 0.85639765 0.98703714]
# 0.9212789097291887
# The difference between the r2 score and cross validation score is 7.811135638163636

# %%
score=cross_val_score(lasso,x,y)
print(score)
print(score.mean())
print('The difference between the r2 score and cross validation score is',(r2_score(y_test,las_pred)-score.mean())*100)
# Out:
# [-42.37117014 -11.06215836  -0.30321946 -32.72956581 -29.0315447 ]
# -23.099531692553747
# The difference between the r2 score and cross validation score is 2298.393142431919

# %% [markdown]
# From our analysis we can see that the difference between r2 score and cross validation score is minimum for linear regression model.
# So we are gonna consider this model for further analysis.

# %% [markdown]
# Linear regression as our best fitting model and best performing model.

# %% [markdown]
# # Hyper Parameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
Parameters={'fit_intercept':[True,False],
           'copy_X':[True,False],
           'n_jobs':[-1.0,1],
           'positive':[True,False]}

# %%
GCV=GridSearchCV(LinearRegression(),Parameters,cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=LinearRegression(),
#              param_grid={'copy_X': [True, False],
#                          'fit_intercept': [True, False], 'n_jobs': [-1.0, 1],
#                          'positive': [True, False]})

# %%
GCV.best_params_
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': -1.0, 'positive': True}

# %%
Model=LinearRegression(copy_X= True, fit_intercept= True, n_jobs= -1.0, positive= True)

# %%
Model.fit(x_train,y_train)
pred=Model.predict(x_test)
print('r2 Score',r2_score(y_test,pred))
print('Mean squared error',mean_squared_error(y_test,pred))
print('Mean absolute error',mean_absolute_error(y_test,pred))
# Out:
# r2 Score 0.9993900321184321
# Mean squared error 0.0007369089445413322
# Mean absolute error 0.022110865808015846

# %% [markdown]
# So here our r2 score is 99.97.

# %%
import joblib
import pickle

# %%
filename='Happinessindex.pkl'
pickle.dump(Model,open(filename,'wb'))

# %% [markdown]
# So we save this model here.

# %% [markdown]
# # QUESTION _2:Titanic Ship Model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns

# %%
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset1/master/titanic_train.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# So this data is having 891 rows and 12 columns. 'Survived' is our target variable and rest of them are features.

# %% [markdown]
# ## Exploratory Data Anaysis

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# So here we are having three types of data. Integer,Float and Object are the types of data.

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.columns.to_list()
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# Here we can see that there are 177 null values in age column, 687 in cabin and 2 in embarked section.

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# from this heatmap we can see that the age column,cabin column is having null values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# Here we can see that this heatmap is having 2 float type column,5 integer type column and 5 object type data types.

# %%
for i in df.columns:
    print(df[i].value_counts)
    print('\n')
# Out:
# <bound method IndexOpsMixin.value_counts of 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 886    887
# 887    888
# 888    889
# 889    890
# 890    891
# Name: PassengerId, Length: 891, dtype: int64>
#
#
# <bound method IndexOpsMixin.value_counts of 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64>
#
#
# <bound method IndexOpsMixin.value_counts of 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64>
#
#
# <bound method IndexOpsMixin.value_counts of 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# ...

# %%
df['Survived'].nunique()
# Out:
# 2

# %% [markdown]
# Here we can see that survived column is having 2 values. It means that this is a classification problem.

# %%
categorical_col=[]
for i in df.dtypes.index:
    if df.dtypes[i]=="object":
        categorical_col.append(i)
print("Categorical column",categorical_col)
print("\n")
# Out:
# Categorical column ['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked']

# %%
numerical_col=[]
for i in df.dtypes.index:
    if df.dtypes[i]!="object":
        numerical_col.append(i)
print("Numerical Column",numerical_col)
print("\n")
# Out:
# Numerical Column ['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']

# %% [markdown]
# We distribute these columns into categorical column and numerical column.

# %%
df.nunique().to_frame("No. of unique value")
# Out:
#              No. of unique value
# PassengerId                  891
# Survived                       2
# Pclass                         3
# Name                         891
# Sex                            2
# Age                           88
# SibSp                          7
# Parch                          7
# Ticket                       681
# Fare                         248
# Cabin                        147
# Embarked                       3

# %% [markdown]
# so here we can see that passengerId,Name,Ticket,Fare and cabin is having more unique value. I think these data is not going to impact the whole data. So we are going to drop these columns.

# %%
df.drop(['PassengerId','Name','Ticket','Fare','Cabin'],axis=1,inplace=True)

# %%
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch Embarked
# 0           0       3    male  22.0      1      0        S
# 1           1       1  female  38.0      1      0        C
# 2           1       3  female  26.0      0      0        S
# 3           1       1  female  35.0      1      0        S
# 4           0       3    male  35.0      0      0        S
# ..        ...     ...     ...   ...    ...    ...      ...
# 886         0       2    male  27.0      0      0        S
# 887         1       1  female  19.0      0      0        S
# 888         0       3  female   NaN      1      2        S
# 889         1       1    male  26.0      0      0        C
# 890         0       3    male  32.0      0      0        Q
#
# [891 rows x 7 columns]

# %%
df['Age'].unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
df['Age'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64>

# %%
df['Embarked'].nunique()
# Out:
# 3

# %% [markdown]
# We have to fill the null values of age with the mean value of age. Otherwise it will show less number of count in describe method.

# %%
df['Age']=df['Age'].fillna(df['Age'].mean())

# %%
print(df['Age'].mean())
# Out:
# 29.699117647058763

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    object
#  3   Age       891 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Embarked  889 non-null    object
# dtypes: float64(1), int64(4), object(2)
# memory usage: 48.9+ KB

# %%
df.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch
# count  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594
# std      0.486592    0.836071   13.002015    1.102743    0.806057
# min      0.000000    1.000000    0.420000    0.000000    0.000000
# 25%      0.000000    2.000000   22.000000    0.000000    0.000000
# 50%      0.000000    3.000000   29.699118    0.000000    0.000000
# 75%      1.000000    3.000000   35.000000    1.000000    0.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000

# %% [markdown]
# It shows the data of all the columns,
#
# It looks like age column is having less count as compare to other column.We have to deal with this.
#
# Mean is more than 50% for survived,age,SibSp and Parch. it means that ti will be right skewed.
#
# Pclass is having less mean value than 50%, it will be left skewed.
#
# Some of the columns is having big difference between 75% and 100%. So there will be some outliers.

# %%
plt.figure(figsize=(22,15))
sns.heatmap(df.describe(),annot=True,fmt='0.2f',linecolor='red',linewidth=0.3)
plt.xlabel('figure',fontsize=10)
plt.yticks('Features',fontsize=10)
plt.title('Descriptice graph',fontsize=10)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\matplotlib\axis.py in convert_units(self, x)
#    1505         try:
# -> 1506             ret = self.converter.convert(x, self.units, self)
#    1507         except Exception as e:
#
# ~\anaconda3\lib\site-packages\matplotlib\category.py in convert(value, unit, axis)
#      48         if unit is None:
# ---> 49             raise ValueError(
#      50                 'Missing category information for StrCategoryConverter; '
#
# ValueError: Missing category information for StrCategoryConverter; this might be caused by unintendedly mixing categorical and numeric data
#
# The above exception was the direct cause of the following exception:
#
# ConversionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14864\4234101286.py in <module>
# ...

# %% [markdown]
# ## Data visualization

# %%
sns.countplot(df['Sex'],palette='colorblind')
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %% [markdown]
# In ship  there are more males than females.

# %%
sns.countplot(df['Survived'],palette='colorblind')
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
sns.countplot(df['Pclass'],palette='colorblind')
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %%
sns.countplot(df['Parch'],palette='colorblind')
# Out:
# <AxesSubplot:xlabel='Parch', ylabel='count'>

# %% [markdown]
# I think that the sex column and region in which passenger belongs has no impack on people will survive or not.So i am going to drop these.

# %%
df.drop(['Sex','Embarked'],axis=1,inplace=True)

# %%
df
# Out:
#      Survived  Pclass        Age  SibSp  Parch
# 0           0       3  22.000000      1      0
# 1           1       1  38.000000      1      0
# 2           1       3  26.000000      0      0
# 3           1       1  35.000000      1      0
# 4           0       3  35.000000      0      0
# ..        ...     ...        ...    ...    ...
# 886         0       2  27.000000      0      0
# 887         1       1  19.000000      0      0
# 888         0       3  29.699118      1      2
# 889         1       1  26.000000      0      0
# 890         0       3  32.000000      0      0
#
# [891 rows x 5 columns]

# %%
plt.figure(figsize=(20,15), facecolor="white")
plotnumber=1
for column in df:
    if plotnumber<=12:
        ax=plt.subplot(3,4,plotnumber)
        sns.distplot(df[column],color='m')
        plt.xlabel(column,fontsize=20)
        plotnumber+=1
plt.show()

# %% [markdown]
# We can see some skewness here, specially in sibsp column and parch column

# %%
plt.figure(figsize=(40,20),facecolor='white')
plotnumber=1
for column in df:
    if plotnumber<=12:
        ax=plt.subplot(4,3,plotnumber)
        sns.boxplot(df[column],palette='bright')
        plt.xlabel(column,fontsize=20)
        plt.yticks(rotation=0,fontsize=20)
        plotnumber+=1
plt.show()

# %% [markdown]
# There are some outliers in age column,sibsp column and parch column

# %%
from scipy.stats import zscore

# %%
df.columns
# Out:
# Index(['Survived', 'Pclass', 'Age', 'SibSp', 'Parch'], dtype='object')

# %%
outliers=df[['Survived', 'Pclass', 'Age', 'SibSp', 'Parch']]
z=np.abs(zscore(outliers))
z
# Out:
#      Survived    Pclass       Age     SibSp     Parch
# 0    0.789272  0.827377  0.592481  0.432793  0.473674
# 1    1.266990  1.566107  0.638789  0.432793  0.473674
# 2    1.266990  0.827377  0.284663  0.474545  0.473674
# 3    1.266990  1.566107  0.407926  0.432793  0.473674
# 4    0.789272  0.827377  0.407926  0.474545  0.473674
# ..        ...       ...       ...       ...       ...
# 886  0.789272  0.369365  0.207709  0.474545  0.473674
# 887  1.266990  1.566107  0.823344  0.474545  0.473674
# 888  0.789272  0.827377  0.000000  0.432793  2.008933
# 889  1.266990  1.566107  0.284663  0.474545  0.473674
# 890  0.789272  0.827377  0.177063  0.474545  0.473674
#
# [891 rows x 5 columns]

# %%
np.where(z<3)
# Out:
# (array([  0,   0,   0, ..., 890, 890, 890], dtype=int64),
#  array([0, 1, 2, ..., 2, 3, 4], dtype=int64))

# %%
df1=df[(z<3).all(axis=1)]

# %%
df1
# Out:
#      Survived  Pclass        Age  SibSp  Parch
# 0           0       3  22.000000      1      0
# 1           1       1  38.000000      1      0
# 2           1       3  26.000000      0      0
# 3           1       1  35.000000      1      0
# 4           0       3  35.000000      0      0
# ..        ...     ...        ...    ...    ...
# 886         0       2  27.000000      0      0
# 887         1       1  19.000000      0      0
# 888         0       3  29.699118      1      2
# 889         1       1  26.000000      0      0
# 890         0       3  32.000000      0      0
#
# [839 rows x 5 columns]

# %%
df1.shape
# Out:
# (839, 5)

# %%
print('Percentage data loss-',((df.shape[0]-df1.shape[0])/df.shape[0]*100))
# Out:
# Percentage data loss- 5.836139169472503

# %% [markdown]
# Because there are data loss only 5%, so we can afford this.

# %%
df=df1

# %%
df.shape
# Out:
# (839, 5)

# %%
y=df['Survived']
x=df.drop(columns=['Survived'])

# %%
x
# Out:
#      Pclass        Age  SibSp  Parch
# 0         3  22.000000      1      0
# 1         1  38.000000      1      0
# 2         3  26.000000      0      0
# 3         1  35.000000      1      0
# 4         3  35.000000      0      0
# ..      ...        ...    ...    ...
# 886       2  27.000000      0      0
# 887       1  19.000000      0      0
# 888       3  29.699118      1      2
# 889       1  26.000000      0      0
# 890       3  32.000000      0      0
#
# [839 rows x 4 columns]

# %%
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 839, dtype: int64

# %%
Q1=x.quantile(0.25)
Q3=x.quantile(0.75)
IQR= Q3 - Q1

# %%
df2=df[~((df<(Q1-1.5*IQR))|(df>(Q3+1.5*IQR))).any(axis=1)]

# %%
df2.shape
# Out:
# (636, 5)

# %%
print('Percentage data loss-',((df.shape[0]-df2.shape[0])/df.shape[0]*100))
# Out:
# Percentage data loss- 24.195470798569726

# %% [markdown]
# Cant afford data loss here.

# %%
df.skew()
# Out:
# Survived    0.417114
# Pclass     -0.568482
# Age         0.321028
# SibSp       2.012240
# Parch       2.039356
# dtype: float64

# %%
df['Pclass']=np.square(df['Pclass'])

# %%
df.skew()
# Out:
# Survived    0.417114
# Pclass     -0.377292
# Age         0.321028
# SibSp       2.012240
# Parch       2.039356
# dtype: float64

# %%
df['SibSp']=np.reciprocal(df['SibSp'])

# %%
df.skew()
# Out:
# Survived    0.417114
# Pclass     -0.377292
# Age         0.321028
# SibSp       0.942078
# Parch       2.039356
# dtype: float64

# %%
df['Parch']=np.reciprocal(df['Parch'])

# %%
df.skew()
# Out:
# Survived    0.417114
# Pclass     -0.377292
# Age         0.321028
# SibSp       0.942078
# Parch       1.510171
# dtype: float64

# %%
df['Parch']=np.sqrt(df['Parch'])

# %%
df.skew()
# Out:
# Survived    0.417114
# Pclass     -0.377292
# Age         0.321028
# SibSp       0.942078
# Parch      -0.619422
# dtype: float64

# %% [markdown]
# this is the maxm skewness we can reduce.

# %%
plt.figure(figsize=(20,15), facecolor="white")
plotnumber=1
for column in df:
    if plotnumber<=12:
        ax=plt.subplot(3,4,plotnumber)
        sns.distplot(df[column],color='m')
        plt.xlabel(column,fontsize=20)
        plotnumber+=1
plt.show()

# %%
cor=df.corr()

# %%
cor
# Out:
#           Survived    Pclass       Age     SibSp     Parch
# Survived  1.000000 -0.333166 -0.086185  0.161758 -0.024770
# Pclass   -0.333166  1.000000 -0.304910 -0.138127  0.069904
# Age      -0.086185 -0.304910  1.000000 -0.104212  0.163569
# SibSp     0.161758 -0.138127 -0.104212  1.000000  0.136212
# Parch    -0.024770  0.069904  0.163569  0.136212  1.000000

# %%
plt.figure(figsize=(22,18))
sns.heatmap(df.corr(),annot=True,linecolor='red',fmt='0.2f')
plt.xlabel('figure',fontsize=12)
plt.ylabel('feature_name',fontsize=12)
plt.title('Correlation between figure and feature name')
plt.show()

# %%
cor['Survived'].sort_values(ascending=False)
# Out:
# Survived    1.000000
# SibSp       0.161758
# Parch      -0.024770
# Age        -0.086185
# Pclass     -0.333166
# Name: Survived, dtype: float64

# %%
plt.figure(figsize=(22,18))
df.corr()['Survived'].sort_values(ascending=False).drop(['Survived']).plot(kind='bar',color='m')
plt.xlabel('feature',fontsize=12)
plt.ylabel('Target',fontsize=12)
plt.title('Barplot between features and target')
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#        Pclass       Age     SibSp     Parch
# 0    0.855887 -0.643615  1.005153 -0.463703
# 1   -1.525835  0.679792  1.005153 -0.463703
# 2    0.855887 -0.312763 -0.559454 -0.463703
# 3   -1.525835  0.431653  1.005153 -0.463703
# 4    0.855887  0.431653 -0.559454 -0.463703
# ..        ...       ...       ...       ...
# 834 -0.334974 -0.230050 -0.559454 -0.463703
# 835 -1.525835 -0.891754 -0.559454 -0.463703
# 836  0.855887 -0.006798  1.005153  2.979190
# 837 -1.525835 -0.312763 -0.559454 -0.463703
# 838  0.855887  0.183514 -0.559454 -0.463703
#
# [839 rows x 4 columns]

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif=pd.DataFrame()
vif["VIF Values"]=[variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif["Features"]=x.columns
vif
# Out:
#    VIF Values Features
# 0    1.166899   Pclass
# 1    1.242210      Age
# 2    1.143444    SibSp
# 3    1.230475    Parch

# %%
y.value_counts()
# Out:
# 0    505
# 1    334
# Name: Survived, dtype: int64

# %%
from imblearn.over_sampling import SMOTE

# %%
SM=SMOTE()
x,y=SM.fit_resample(x,y)

# %%
y.value_counts()
# Out:
# 0    505
# 1    505
# Name: Survived, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
MaxACC= 0
MaxRS= 0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25, random_state=i)
    RFR=RandomForestClassifier()
    RFR.fit(x_train,y_train)
    pred=RFR.predict(x_test)
    Accu=accuracy_score(y_test,pred)
    if Accu>MaxACC:
        MaxACC=Accu
        MaxRS= i
print("Best Accuracy is", MaxACC,"At random variable", MaxRS)
# Out:
# Best Accuracy is 0.7312252964426877 At random variable 71

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25, random_state= MaxRS)

# %%
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier,AdaBoostClassifier, BaggingClassifier
from sklearn.metrics import classification_report,confusion_matrix,roc_curve,accuracy_score
from sklearn.model_selection import cross_val_score

# %%
RFC=RandomForestClassifier()
RFC.fit(x_train,y_train)
predRFC=RFC.predict(x_test)
print(accuracy_score(y_test,predRFC))
print(confusion_matrix(y_test,predRFC))
print(classification_report(y_test,predRFC))
# Out:
# 0.7272727272727273
# [[94 36]
#  [33 90]]
#               precision    recall  f1-score   support
#
#            0       0.74      0.72      0.73       130
#            1       0.71      0.73      0.72       123
#
#     accuracy                           0.73       253
#    macro avg       0.73      0.73      0.73       253
# weighted avg       0.73      0.73      0.73       253

# %%
LR=LogisticRegression()
LR.fit(x_train,y_train)
predLR=LR.predict(x_test)
print(accuracy_score(y_test,predLR))
print(confusion_matrix(y_test,predLR))
print(classification_report(y_test,predLR))
# Out:
# 0.6679841897233202
# [[87 43]
#  [41 82]]
#               precision    recall  f1-score   support
#
#            0       0.68      0.67      0.67       130
#            1       0.66      0.67      0.66       123
#
#     accuracy                           0.67       253
#    macro avg       0.67      0.67      0.67       253
# weighted avg       0.67      0.67      0.67       253

# %%
svc=SVC()
svc.fit(x_train,y_train)
predSVC=svc.predict(x_test)
print(accuracy_score(y_test,predSVC))
print(confusion_matrix(y_test,predSVC))
print(classification_report(y_test,predSVC))
# Out:
# 0.7075098814229249
# [[89 41]
#  [33 90]]
#               precision    recall  f1-score   support
#
#            0       0.73      0.68      0.71       130
#            1       0.69      0.73      0.71       123
#
#     accuracy                           0.71       253
#    macro avg       0.71      0.71      0.71       253
# weighted avg       0.71      0.71      0.71       253

# %%
GB=GradientBoostingClassifier()
GB.fit(x_train,y_train)
predGB=GB.predict(x_test)
print(accuracy_score(y_test,predGB))
print(confusion_matrix(y_test,predGB))
print(classification_report(y_test,predGB))
# Out:
# 0.6837944664031621
# [[90 40]
#  [40 83]]
#               precision    recall  f1-score   support
#
#            0       0.69      0.69      0.69       130
#            1       0.67      0.67      0.67       123
#
#     accuracy                           0.68       253
#    macro avg       0.68      0.68      0.68       253
# weighted avg       0.68      0.68      0.68       253

# %%
ETC=ExtraTreesClassifier()
ETC.fit(x_train,y_train)
predETC=ETC.predict(x_test)
print(accuracy_score(y_test,predETC))
print(confusion_matrix(y_test,predETC))
print(classification_report(y_test,predETC))
# Out:
# 0.7114624505928854
# [[101  29]
#  [ 44  79]]
#               precision    recall  f1-score   support
#
#            0       0.70      0.78      0.73       130
#            1       0.73      0.64      0.68       123
#
#     accuracy                           0.71       253
#    macro avg       0.71      0.71      0.71       253
# weighted avg       0.71      0.71      0.71       253

# %%
from sklearn.model_selection import cross_val_score

# %%
score=cross_val_score(RFC,x,y)
print(score)
print(score.mean())
print("Difference between accuracy score and cross validation score",accuracy_score(y_test,predRFC)-score.mean())
# Out:
# [0.63861386 0.67326733 0.6980198  0.73267327 0.6980198 ]
# 0.6881188118811881
# Difference between accuracy score and cross validation score 0.03915391539153923

# %%
score=cross_val_score(LR,x,y)
print(score)
print(score.mean())
print("Difference between accuracy score and cross validation score",accuracy_score(y_test,predLR)-score.mean())
# Out:
# [0.57920792 0.65841584 0.73762376 0.6980198  0.71782178]
# 0.6782178217821782
# Difference between accuracy score and cross validation score -0.010233632058857967

# %%
score=cross_val_score(svc,x,y)
print(score)
print(score.mean())
print("Difference between accuracy score and cross validation score",accuracy_score(y_test,predSVC)-score.mean())
# Out:
# [0.5990099  0.66336634 0.74257426 0.70792079 0.6980198 ]
# 0.6821782178217821
# Difference between accuracy score and cross validation score 0.025331663601142806

# %%
score=cross_val_score(GB,x,y)
print(score)
print(score.mean())
print("Difference between accuracy score and cross validation score",accuracy_score(y_test,predGB)-score.mean())
# Out:
# [0.63861386 0.64851485 0.74752475 0.71782178 0.7029703 ]
# 0.691089108910891
# Difference between accuracy score and cross validation score -0.007294642507728932

# %%
score=cross_val_score(ETC,x,y)
print(score)
print(score.mean())
print("Difference between accuracy score and cross validation score",accuracy_score(y_test,predETC)-score.mean())
# Out:
# [0.64851485 0.66831683 0.68811881 0.74257426 0.69306931]
# 0.6881188118811881
# Difference between accuracy score and cross validation score 0.023343638711697312

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV

Parameters= {'criterion':['gini', 'entropy', 'log_loss'],
             'class_weight':['balanced', 'balanced_subsample'],
             'warm_start':[True,False],
             'oob_score':[True,False]}

# %%
GCV=GridSearchCV(ExtraTreesClassifier(),Parameters,cv=5)

# %%
 GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=ExtraTreesClassifier(),
#              param_grid={'class_weight': ['balanced', 'balanced_subsample'],
#                          'criterion': ['gini', 'entropy', 'log_loss'],
#                          'oob_score': [True, False],
#                          'warm_start': [True, False]})

# %%
GCV.best_params_
# Out:
# {'class_weight': 'balanced_subsample',
#  'criterion': 'entropy',
#  'oob_score': False,
#  'warm_start': False}

# %%
final_model=GradientBoostingClassifier(criterion= 'friedman_mse', loss= 'deviance',max_features= 'auto',random_state= 500)
final_model.fit(x_train,y_train)
pred=final_model.predict(x_test)
acc=accuracy_score(y_test,pred)
print(acc*100)
# Out:
# 68.37944664031622

# %%
import joblib

# %%
joblib.dump(final_model,"Titanmodel.pkl")
# Out:
# ['Titanmodel.pkl']
