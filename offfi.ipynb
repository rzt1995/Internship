# %%
import numpy as np
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset4/main/Grades.csv')
df
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 0    CS-97001     B-     D+     C-         C     C-     D+      D     C-
# 1    CS-97002      A      D     D+         D     B-      C      D      A
# 2    CS-97003      A      B      A        B-     B+      A     B-     B+
# 3    CS-97004      D     C+     D+         D      D     A-     D+     C-
# 4    CS-97005     A-     A-     A-        B+      A      A     A-     B+
# ..        ...    ...    ...    ...       ...    ...    ...    ...    ...
# 566  CS-97567      B      A      A        A-     A+      A     A-     A-
# 567  CS-97568     A+      A      A         A      A      A      A     A-
# 568  CS-97569      B      A     A-        B+      A      A      A      A
# 569  CS-97570      A     B+      D         A      D     D+     B-     C-
# 570  CS-97571      C      D      D         C      C     D+      B     C+
#
#     EE-119  ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423  \
# 0       B-  ...     C-     C-     C-     C-     A-      A     C-      B
# 1       D+  ...     D+      D      C      D     A-     B-      C      C
# 2       A-  ...      B      B      A      C      A      A      A     A-
# 3        D  ...     D+      C     D+     C-     B-      B     C+     C+
# 4        A  ...     B-     B+     B+     B-     A-      A     A-     A-
# ..     ...  ...    ...    ...    ...    ...    ...    ...    ...    ...
# 566     A+  ...     A-     A-      A      A      A     B+     B+      B
# 567      A  ...     B+     B+      A      A     A-      B     A-      C
# 568      A  ...     A-      B      A     B+      A      C     B+     A-
# 569     B-  ...      D      B      B     C-      D      C      B     B-
# 570      C  ...     C+      C     B-      D      F     C-     B+      D
#
#     CS-412   CGPA
# 0       A-  2.205
# 1        B  2.008
# 2        A  3.608
# 3       C+  1.906
# 4        A  3.448
# ..     ...    ...
# 566      A  3.798
# 567     A-  3.772
# 568     A-  3.470
# 569      C  2.193
# 570     C-  1.753
#
# [571 rows x 43 columns]

# %%
df.head()
# Out:
#    Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119  \
# 0  CS-97001     B-     D+     C-         C     C-     D+      D     C-     B-
# 1  CS-97002      A      D     D+         D     B-      C      D      A     D+
# 2  CS-97003      A      B      A        B-     B+      A     B-     B+     A-
# 3  CS-97004      D     C+     D+         D      D     A-     D+     C-      D
# 4  CS-97005     A-     A-     A-        B+      A      A     A-     B+      A
#
#    ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423 CS-412   CGPA
# 0  ...     C-     C-     C-     C-     A-      A     C-      B     A-  2.205
# 1  ...     D+      D      C      D     A-     B-      C      C      B  2.008
# 2  ...      B      B      A      C      A      A      A     A-      A  3.608
# 3  ...     D+      C     D+     C-     B-      B     C+     C+     C+  1.906
# 4  ...     B-     B+     B+     B-     A-      A     A-     A-      A  3.448
#
# [5 rows x 43 columns]

# %%
df['PH-121'].unique
# Out:
# <bound method Series.unique of 0      B-
# 1       A
# 2       A
# 3       D
# 4      A-
#        ..
# 566     B
# 567    A+
# 568     B
# 569     A
# 570     C
# Name: PH-121, Length: 571, dtype: object>

# %%
df['PH-121'].value_counts()
# Out:
# A-    112
# A     111
# B+     61
# B      57
# B-     56
# D      44
# C      33
# C+     31
# D+     22
# A+     22
# C-     19
# WU      2
# F       1
# Name: PH-121, dtype: int64

# %%
df.dtypes
# Out:
# Seat No.      object
# PH-121        object
# HS-101        object
# CY-105        object
# HS-105/12     object
# MT-111        object
# CS-105        object
# CS-106        object
# EL-102        object
# EE-119        object
# ME-107        object
# CS-107        object
# HS-205/20     object
# MT-222        object
# EE-222        object
# MT-224        object
# CS-210        object
# CS-211        object
# CS-203        object
# CS-214        object
# EE-217        object
# CS-212        object
# CS-215        object
# MT-331        object
# EF-303        object
# HS-304        object
# CS-301        object
# CS-302        object
# TC-383        object
# MT-442        object
# EL-332        object
# CS-318        object
# CS-306        object
# CS-312        object
# CS-317        object
# CS-403        object
# CS-421        object
# CS-406        object
# CS-414        object
# CS-419        object
# CS-423        object
# CS-412        object
# CGPA         float64
# dtype: object

# %%
df.replace({'A':2,'A+':1,'A-':3,'B+':4,'B':5,'B-':6,'C+':7,'C':8,'C-':9,'D+':10,'D':11,'D-':12,'F':0,'WU':0},inplace=True)

# %%
df
# Out:
#      Seat No.  PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  \
# 0    CS-97001       6      10     9.0        8.0     9.0      10    11.0
# 1    CS-97002       2      11    10.0       11.0     6.0       8    11.0
# 2    CS-97003       2       5     2.0        6.0     4.0       2     6.0
# 3    CS-97004      11       7    10.0       11.0    11.0       3    10.0
# 4    CS-97005       3       3     3.0        4.0     2.0       2     3.0
# ..        ...     ...     ...     ...        ...     ...     ...     ...
# 566  CS-97567       5       2     2.0        3.0     1.0       2     3.0
# 567  CS-97568       1       2     2.0        2.0     2.0       2     2.0
# 568  CS-97569       5       2     3.0        4.0     2.0       2     2.0
# 569  CS-97570       2       4    11.0        2.0    11.0      10     6.0
# 570  CS-97571       8      11    11.0        8.0     8.0      10     5.0
#
#      EL-102  EE-119  ...  CS-312 CS-317  CS-403 CS-421 CS-406 CS-414 CS-419  \
# 0       9.0     6.0  ...       9    9.0     9.0      9      3      2    9.0
# 1       2.0    10.0  ...      10   11.0     8.0     11      3      6    8.0
# 2       4.0     3.0  ...       5    5.0     2.0      8      2      2    2.0
# 3       9.0    11.0  ...      10    8.0    10.0      9      6      5    7.0
# 4       4.0     2.0  ...       6    4.0     4.0      6      3      2    3.0
# ..      ...     ...  ...     ...    ...     ...    ...    ...    ...    ...
# 566     3.0     1.0  ...       3    3.0     2.0      2      2      4    4.0
# 567     3.0     2.0  ...       4    4.0     2.0      2      3      5    3.0
# 568     2.0     2.0  ...       3    5.0     2.0      4      2      8    4.0
# 569     9.0     6.0  ...      11    5.0     5.0      9     11      8    5.0
# 570     7.0     8.0  ...       7    8.0     6.0     11      0      9    4.0
#
#     CS-423 CS-412   CGPA
# 0      5.0      3  2.205
# 1      8.0      5  2.008
# 2      3.0      2  3.608
# 3      7.0      7  1.906
# 4      3.0      2  3.448
# ..     ...    ...    ...
# 566    5.0      2  3.798
# 567    8.0      3  3.772
# 568    3.0      3  3.470
# 569    6.0      8  2.193
# 570   11.0      9  1.753
#
# [571 rows x 43 columns]

# %%
df
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 0    CS-97001     B-     D+     C-         C     C-     D+      D     C-
# 1    CS-97002      2      D     D+         D     B-      C      D      2
# 2    CS-97003      2      B      2        B-     B+      2     B-     B+
# 3    CS-97004      D     C+     D+         D      D     A-     D+     C-
# 4    CS-97005     A-     A-     A-        B+      2      2     A-     B+
# ..        ...    ...    ...    ...       ...    ...    ...    ...    ...
# 566  CS-97567      B      2      2        A-     A+      2     A-     A-
# 567  CS-97568     A+      2      2         2      2      2      2     A-
# 568  CS-97569      B      2     A-        B+      2      2      2      2
# 569  CS-97570      2     B+      D         2      D     D+     B-     C-
# 570  CS-97571      C      D      D         C      C     D+      B     C+
#
#     EE-119  ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423  \
# 0       B-  ...     C-     C-     C-     C-     A-      2     C-      B
# 1       D+  ...     D+      D      C      D     A-     B-      C      C
# 2       A-  ...      B      B      2      C      2      2      2     A-
# 3        D  ...     D+      C     D+     C-     B-      B     C+     C+
# 4        2  ...     B-     B+     B+     B-     A-      2     A-     A-
# ..     ...  ...    ...    ...    ...    ...    ...    ...    ...    ...
# 566     A+  ...     A-     A-      2      2      2     B+     B+      B
# 567      2  ...     B+     B+      2      2     A-      B     A-      C
# 568      2  ...     A-      B      2     B+      2      C     B+     A-
# 569     B-  ...      D      B      B     C-      D      C      B     B-
# 570      C  ...     C+      C     B-      D      F     C-     B+      D
#
#     CS-412   CGPA
# 0       A-  2.205
# 1        B  2.008
# 2        2  3.608
# 3       C+  1.906
# 4        2  3.448
# ..     ...    ...
# 566      2  3.798
# 567     A-  3.772
# 568     A-  3.470
# 569      C  2.193
# 570     C-  1.753
#
# [571 rows x 43 columns]

# %%
df.isnull().sum()
# Out:
# Seat No.      0
# PH-121        0
# HS-101        0
# CY-105        1
# HS-105/12     1
# MT-111        2
# CS-105        0
# CS-106        2
# EL-102        2
# EE-119        2
# ME-107        2
# CS-107        2
# HS-205/20     5
# MT-222        5
# EE-222        7
# MT-224        7
# CS-210        7
# CS-211        5
# CS-203        5
# CS-214        6
# EE-217        6
# CS-212        6
# CS-215        6
# MT-331        9
# EF-303       10
# HS-304       10
# CS-301       10
# CS-302       10
# TC-383       10
# MT-442       10
# EL-332        9
# CS-318        9
# CS-306        9
# CS-312       10
# CS-317       12
# CS-403       12
# CS-421       12
# CS-406       85
# CS-414       13
# CS-419       13
# CS-423       14
# CS-412       79
# CGPA          0
# dtype: int64

# %%
df['CY-105'].unique()
# Out:
# array(['C-', 'D+', 2, 'A-', 'B', 'C+', 'B+', 'B-', 'C', 'D', nan, 'WU',
#        'A+', 'F'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
x=df.drop('CGPA',axis=True)
y=df['CGPA']

# %%
x
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 0    CS-97001     B-     D+     C-         C     C-     D+      D     C-
# 1    CS-97002      A      D     D+         D     B-      C      D      A
# 2    CS-97003      A      B      A        B-     B+      A     B-     B+
# 3    CS-97004      D     C+     D+         D      D     A-     D+     C-
# 4    CS-97005     A-     A-     A-        B+      A      A     A-     B+
# ..        ...    ...    ...    ...       ...    ...    ...    ...    ...
# 566  CS-97567      B      A      A        A-     A+      A     A-     A-
# 567  CS-97568     A+      A      A         A      A      A      A     A-
# 568  CS-97569      B      A     A-        B+      A      A      A      A
# 569  CS-97570      A     B+      D         A      D     D+     B-     C-
# 570  CS-97571      C      D      D         C      C     D+      B     C+
#
#     EE-119  ... CS-306 CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419  \
# 0       B-  ...      C     C-     C-     C-     C-     A-      A     C-
# 1       D+  ...      D     D+      D      C      D     A-     B-      C
# 2       A-  ...     A-      B      B      A      C      A      A      A
# 3        D  ...     C-     D+      C     D+     C-     B-      B     C+
# 4        A  ...     A-     B-     B+     B+     B-     A-      A     A-
# ..     ...  ...    ...    ...    ...    ...    ...    ...    ...    ...
# 566     A+  ...     B+     A-     A-      A      A      A     B+     B+
# 567      A  ...     A-     B+     B+      A      A     A-      B     A-
# 568      A  ...     B+     A-      B      A     B+      A      C     B+
# 569     B-  ...     B+      D      B      B     C-      D      C      B
# 570      C  ...     D+     C+      C     B-      D      F     C-     B+
#
#     CS-423 CS-412
# 0        B     A-
# 1        C      B
# 2       A-      A
# 3       C+     C+
# 4       A-      A
# ..     ...    ...
# 566      B      A
# 567      C     A-
# 568     A-     A-
# 569     B-      C
# 570      D     C-
#
# [571 rows x 42 columns]

# %%
le=LabelEncoder()
df_e=le.fit_transform(df['PH-121','HS-101'])
pd.Series(df_e)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ana\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# C:\ana\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# C:\ana\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('PH-121', 'HS-101')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13996\1551645905.py in <module>
#       1 le=LabelEncoder()
# ----> 2 df_e=le.fit_transform(df['PH-121','HS-101'])
#       3 pd.Series(df_e)
#
# C:\ana\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# C:\ana\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: ('PH-121', 'HS-101')
