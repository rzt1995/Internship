# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset3/main/glass.csv')
df
# Out:
#        1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.00.1  1.1
# 0      2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00    0.00    1
# 1      3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00    0.00    1
# 2      4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00    0.00    1
# 3      5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00    0.00    1
# 4      6  1.51596  12.79  3.61  1.62  72.97  0.64  8.07  0.00    0.26    1
# ..   ...      ...    ...   ...   ...    ...   ...   ...   ...     ...  ...
# 208  210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06    0.00    7
# 209  211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59    0.00    7
# 210  212  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64    0.00    7
# 211  213  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57    0.00    7
# 212  214  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67    0.00    7
#
# [213 rows x 11 columns]

# %%
df.columns=['Id','RI','Na','Mg','Al','Si','K','Ca','Ba','Fe','Glass_type']

# %%
df
# Out:
#       Id       RI     Na    Mg    Al     Si     K    Ca    Ba    Fe  \
# 0      2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.00
# 1      3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.00
# 2      4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.00
# 3      5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.00
# 4      6  1.51596  12.79  3.61  1.62  72.97  0.64  8.07  0.00  0.26
# ..   ...      ...    ...   ...   ...    ...   ...   ...   ...   ...
# 208  210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.00
# 209  211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.00
# 210  212  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.00
# 211  213  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.00
# 212  214  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.00
#
#      Glass_type
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ..          ...
# 208           7
# ...

# %%
df.drop(['Id'],axis=1,inplace=True)

# %%
df
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba    Fe  Glass_type
# 0    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.00           1
# 1    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.00           1
# 2    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.00           1
# 3    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.00           1
# 4    1.51596  12.79  3.61  1.62  72.97  0.64  8.07  0.00  0.26           1
# ..       ...    ...   ...   ...    ...   ...   ...   ...   ...         ...
# 208  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.00           7
# 209  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.00           7
# 210  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.00           7
# 211  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.00           7
# 212  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.00           7
#
# [213 rows x 10 columns]

# %%
df.head()
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba    Fe  Glass_type
# 0  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.00           1
# 1  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.00           1
# 2  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.00           1
# 3  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.00           1
# 4  1.51596  12.79  3.61  1.62  72.97  0.64  8.07  0.0  0.26           1

# %%
df.describe()
# Out:
#                RI          Na          Mg          Al          Si           K  \
# count  213.000000  213.000000  213.000000  213.000000  213.000000  213.000000
# mean     1.518353   13.406761    2.676056    1.446526   72.655023    0.499108
# std      0.003039    0.818371    1.440453    0.499882    0.774052    0.653035
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516520   12.900000    2.090000    1.190000   72.280000    0.130000
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.560000
# 75%      1.519150   13.830000    3.600000    1.630000   73.090000    0.610000
# max      1.533930   17.380000    3.980000    3.500000   75.410000    6.210000
#
#                Ca          Ba          Fe  Glass_type
# count  213.000000  213.000000  213.000000  213.000000
# mean     8.957934    0.175869    0.057277    2.788732
# std      1.426435    0.498245    0.097589    2.105130
# ...

# %%
df.isnull().sum()
# Out:
# RI            0
# Na            0
# Mg            0
# Al            0
# Si            0
# K             0
# Ca            0
# Ba            0
# Fe            0
# Glass_type    0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213 entries, 0 to 212
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   RI          213 non-null    float64
#  1   Na          213 non-null    float64
#  2   Mg          213 non-null    float64
#  3   Al          213 non-null    float64
#  4   Si          213 non-null    float64
#  5   K           213 non-null    float64
#  6   Ca          213 non-null    float64
#  7   Ba          213 non-null    float64
#  8   Fe          213 non-null    float64
#  9   Glass_type  213 non-null    int64
# dtypes: float64(9), int64(1)
# memory usage: 16.8 KB

# %%
for i in df.columns:
    print(df[i].value_counts)
    print('\n')
# Out:
# <bound method IndexOpsMixin.value_counts of 0      1.51761
# 1      1.51618
# 2      1.51766
# 3      1.51742
# 4      1.51596
#         ...
# 208    1.51623
# 209    1.51685
# 210    1.52065
# 211    1.51651
# 212    1.51711
# Name: RI, Length: 213, dtype: float64>
#
#
# <bound method IndexOpsMixin.value_counts of 0      13.89
# 1      13.53
# 2      13.21
# 3      13.27
# 4      12.79
#        ...
# 208    14.14
# 209    14.92
# 210    14.36
# 211    14.38
# 212    14.23
# Name: Na, Length: 213, dtype: float64>
#
#
# <bound method IndexOpsMixin.value_counts of 0      3.60
# 1      3.55
# 2      3.69
# 3      3.62
# 4      3.61
#        ...
# 208    0.00
# 209    0.00
# 210    0.00
# 211    0.00
# 212    0.00
# Name: Mg, Length: 213, dtype: float64>
#
#
# <bound method IndexOpsMixin.value_counts of 0      1.36
# 1      1.54
# 2      1.29
# 3      1.24
# 4      1.62
#        ...
# 208    2.88
# 209    1.99
# 210    2.02
# 211    1.94
# 212    2.08
# ...

# %%
df['Glass_type'].unique()
# Out:
# array([1, 2, 3, 5, 6, 7], dtype=int64)

# %%
df['Glass_type'].value_counts()
# Out:
# 2    76
# 1    69
# 7    29
# 3    17
# 5    13
# 6     9
# Name: Glass_type, dtype: int64

# %%
plt.figure(figsize=(22,15))
sns.heatmap(df.describe(),annot=True,fmt='0.2f',linecolor='blue',linewidth=0.3)
plt.xlabel('figure',fontsize=10)
plt.yticks('Features',fontsize=10)
plt.title('Descriptice graph',fontsize=10)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\matplotlib\axis.py in convert_units(self, x)
#    1505         try:
# -> 1506             ret = self.converter.convert(x, self.units, self)
#    1507         except Exception as e:
#
# ~\anaconda3\lib\site-packages\matplotlib\category.py in convert(value, unit, axis)
#      48         if unit is None:
# ---> 49             raise ValueError(
#      50                 'Missing category information for StrCategoryConverter; '
#
# ValueError: Missing category information for StrCategoryConverter; this might be caused by unintendedly mixing categorical and numeric data
#
# The above exception was the direct cause of the following exception:
#
# ConversionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26556\3059615016.py in <module>
# ...

# %%
plt.figure(figsize=(20,15), facecolor="white")
plotnumber=1
for column in df:
    if plotnumber<=12:
        ax=plt.subplot(3,4,plotnumber)
        sns.distplot(df[column],color='m')
        plt.xlabel(column,fontsize=20)
        plotnumber+=1
plt.show()

# %%
df.columns.to_list()
# Out:
# ['RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe', 'Glass_type']

# %%
plt.title('comparison between Mg and Al')
sns.scatterplot(x='Mg',y='Al', data=df, hue='Glass_type', palette='bright')
plt.show()

# %%
plt.title('comparison between RI and Na')
sns.scatterplot(x='RI',y='Na', data=df, hue='Glass_type', palette='bright')
plt.show()

# %%
plt.title('comparison between Si and K')
sns.scatterplot(x='Si',y='K', data=df, hue='Glass_type', palette='bright')
plt.show()

# %%
plt.title('comparison between Ba and Fe')
sns.scatterplot(x='Ba',y='Fe', data=df, hue='Glass_type', palette='bright')
plt.show()

# %%
sns.pairplot(df,hue='Glass_type',palette='bright')
plt.show()

# %%
plt.figure(figsize=(40,20),facecolor='white')
plotnumber=1
for column in df:
    if plotnumber<=12:
        ax=plt.subplot(4,3,plotnumber)
        sns.boxplot(df[column],palette='bright')
        plt.xlabel(column,fontsize=20)
        plt.yticks(rotation=0,fontsize=20)
        plotnumber+=1
plt.show()

# %%
from scipy.stats import zscore

# %%
y=df['Glass_type']
x=df.drop(columns=['Glass_type'])

# %%
z=np.abs(zscore(x))
z
# Out:
#            RI        Na        Mg        Al        Si         K        Ca  \
# 0    0.245101  0.591880  0.642937  0.173500  0.097091  0.029329  0.792599
# 1    0.716826  0.150946  0.608144  0.187433  0.433777  0.167472  0.827734
# 2    0.228607  0.240996  0.705564  0.313863  0.058303  0.108813  0.518546
# 3    0.307777  0.167507  0.656854  0.414122  0.550322  0.078115  0.623951
# 4    0.789399  0.755419  0.649895  0.347848  0.407878  0.216258  0.623951
# ..        ...       ...       ...       ...       ...       ...       ...
# 208  0.700332  0.898085  1.862164  2.874379  0.058303  0.643296  0.156046
# 209  0.495808  1.853443  1.862164  1.089766  0.524423  0.766090  0.392060
# 210  0.757727  1.167545  1.862164  1.149921  0.990604  0.766090  0.363952
# 211  0.607966  1.192041  1.862164  0.989506  1.236644  0.766090  0.335844
# 212  0.410039  1.008318  1.862164  1.270232  0.912907  0.766090  0.237466
#
#            Ba        Fe
# 0    0.353808  0.588301
# 1    0.353808  0.588301
# ...

# %%
np.where(z>3)
# Out:
# (array([104, 105, 105, 105, 105, 105, 106, 106, 106, 109, 110, 111, 111,
#         130, 144, 161, 162, 162, 162, 170, 170, 171, 171, 173, 183, 183,
#         187, 188, 200, 200, 202, 206, 212], dtype=int64),
#  array([6, 0, 1, 4, 6, 7, 0, 4, 6, 6, 6, 0, 6, 6, 8, 8, 3, 4, 7, 3, 5, 3,
#         5, 8, 1, 4, 4, 7, 4, 5, 7, 7, 7], dtype=int64))

# %%
z.iloc[104,6]
# Out:
# 3.00900736343217

# %%
df1=df[(z<3).all(axis=1)]
df1
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba    Fe  Glass_type
# 0    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.00           1
# 1    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.00           1
# 2    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.00           1
# 3    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.00           1
# 4    1.51596  12.79  3.61  1.62  72.97  0.64  8.07  0.00  0.26           1
# ..       ...    ...   ...   ...    ...   ...   ...   ...   ...         ...
# 207  1.51640  14.37  0.00  2.74  72.85  0.00  9.45  0.54  0.00           7
# 208  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.00           7
# 209  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.00           7
# 210  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.00           7
# 211  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.00           7
#
# [193 rows x 10 columns]

# %%
df1.shape[0]
# Out:
# 193

# %%
df.shape[0]
# Out:
# 213

# %%
print('Percentage of data loss =',((df.shape[0]-df1.shape[0])/df.shape[0])*100)
# Out:
# Percentage of data loss = 9.389671361502346

# %%
df=df1

# %%
df.shape[0]
# Out:
# 193

# %%
df.describe()
# Out:
#                RI          Na          Mg          Al          Si           K  \
# count  193.000000  193.000000  193.000000  193.000000  193.000000  193.000000
# mean     1.518046   13.415803    2.871658    1.424404   72.725492    0.433472
# std      0.002284    0.674850    1.306938    0.444327    0.582410    0.281741
# min      1.511310   11.030000    0.000000    0.290000   70.570000    0.000000
# 25%      1.516510   12.940000    2.850000    1.190000   72.380000    0.140000
# 50%      1.517630   13.300000    3.500000    1.360000   72.830000    0.560000
# 75%      1.518980   13.790000    3.610000    1.610000   73.090000    0.600000
# max      1.527250   15.150000    3.980000    2.880000   74.550000    1.760000
#
#                Ca          Ba          Fe  Glass_type
# count  193.000000  193.000000  193.000000  193.000000
# mean     8.825026    0.123990    0.051865    2.626943
# std      0.991712    0.357943    0.085924    2.032471
# ...

# %%
plt.figure(figsize=(40,20),facecolor='white')
plotnumber=1
for column in df:
    if plotnumber<=12:
        ax=plt.subplot(4,3,plotnumber)
        sns.boxplot(df[column],palette='bright')
        plt.xlabel(column,fontsize=20)
        plt.yticks(rotation=0,fontsize=20)
        plotnumber+=1
plt.show()

# %%
Q1=x.quantile(0.25)
Q3=x.quantile(0.75)
IQR= Q3 - Q1

# %%
df2=df[~((df<(Q1-1.5*IQR))|(df>(Q3+1.5*IQR))).any(axis=1)]

# %%
df2.shape
# Out:
# (135, 10)

# %%
print('Percentage data loss-',((df.shape[0]-df2.shape[0])/df.shape[0]*100))
# Out:
# Percentage data loss- 30.05181347150259

# %%
df=df1

# %%
y=df['Glass_type']
x=df.drop(columns=['Glass_type'])

# %%
x.shape
# Out:
# (193, 9)

# %%
df.skew()
# Out:
# RI            0.971729
# Na            0.375857
# Mg           -1.533664
# Al            0.649917
# Si           -0.436288
# K             0.297900
# Ca            1.074092
# Ba            3.178256
# Fe            1.478611
# Glass_type    1.277279
# dtype: float64

# %%
x.skew()
# Out:
# RI    0.971729
# Na    0.375857
# Mg   -1.533664
# Al    0.649917
# Si   -0.436288
# K     0.297900
# Ca    1.074092
# Ba    3.178256
# Fe    1.478611
# dtype: float64

# %%
df['RI']=np.cbrt(df['RI'])

# %%
df.skew()
# Out:
# RI            0.966994
# Na            0.375857
# Mg           -1.533664
# Al            0.649917
# Si           -0.436288
# K             0.297900
# Ca            1.074092
# Ba            3.178256
# Fe            1.478611
# Glass_type    1.277279
# dtype: float64

# %%
df['RI']=np.log(df['RI'])

# %%
df.skew()
# Out:
# RI            0.964627
# Na            0.375857
# Mg           -1.533664
# Al            0.649917
# Si           -0.436288
# K             0.297900
# Ca            1.074092
# Ba            3.178256
# Fe            1.478611
# Glass_type    1.277279
# dtype: float64

# %%
 df['Mg']=np.square(df['Mg'])

# %%
df.skew()
# Out:
# RI            0.964627
# Na            0.375857
# Mg           -1.168312
# Al            0.649917
# Si           -0.436288
# K             0.297900
# Ca            1.074092
# Ba            3.178256
# Fe            1.478611
# Glass_type    1.277279
# dtype: float64

# %%
 df['Mg']=np.square(df['Mg'])

# %%
df.skew()
# Out:
# RI            0.964627
# Na            0.375857
# Mg           -0.659528
# Al            0.649917
# Si           -0.436288
# K             0.297900
# Ca            1.074092
# Ba            3.178256
# Fe            1.478611
# Glass_type    1.277279
# dtype: float64

# %%
 df['Mg']=np.square(df['Mg'])

# %%
df.skew()
# Out:
# RI            0.964627
# Na            0.375857
# Mg            0.281391
# Al            0.649917
# Si           -0.436288
# K             0.297900
# Ca            1.074092
# Ba            3.178256
# Fe            1.478611
# Glass_type    1.277279
# dtype: float64

# %%
df['Al']=np.sqrt(df['Al'])

# %%
df.skew()
# Out:
# RI            0.964627
# Na            0.375857
# Mg            0.281391
# Al           -0.103917
# Si           -0.436288
# K             0.297900
# Ca            1.074092
# Ba            3.178256
# Fe            1.478611
# Glass_type    1.277279
# dtype: float64

# %%
df['Ca']=np.sqrt(df['Ca'])

# %%
df.skew()
# Out:
# RI            0.964627
# Na            0.375857
# Mg            0.281391
# Al           -0.103917
# Si           -0.436288
# K             0.297900
# Ca            0.735522
# Ba            3.178256
# Fe            1.478611
# Glass_type    1.277279
# dtype: float64

# %%
df['Ca']=np.sqrt(df['Ca'])

# %%
df.skew()
# Out:
# RI            0.964627
# Na            0.375857
# Mg            0.281391
# Al           -0.103917
# Si           -0.436288
# K             0.297900
# Ca            0.544086
# Ba            3.178256
# Fe            1.478611
# Glass_type    1.277279
# dtype: float64

# %%
df['Ba']=np.sqrt(df['Ba'])

# %%
df.skew()
# Out:
# RI            0.964627
# Na            0.375857
# Mg            0.281391
# Al           -0.103917
# Si           -0.436288
# K             0.297900
# Ca            0.544086
# Ba            2.455886
# Fe            1.478611
# Glass_type    1.277279
# dtype: float64

# %%
x['Fe']=np.sqrt(x['Fe'])

# %%
df.skew()
# Out:
# RI            0.964627
# Na            0.375857
# Mg            0.281391
# Al           -0.103917
# Si           -0.436288
# K             0.297900
# Ca            0.544086
# Ba            2.455886
# Fe            1.478611
# Glass_type    1.277279
# dtype: float64

# %%
plt.figure(figsize=(20,15), facecolor="white")
plotnumber=1
for column in df:
    if plotnumber<=12:
        ax=plt.subplot(3,4,plotnumber)
        sns.distplot(df[column],color='m')
        plt.xlabel(column,fontsize=20)
        plotnumber+=1
plt.show()

# %%
cor=df.corr()
cor
# Out:
#                   RI        Na        Mg        Al        Si         K  \
# RI          1.000000  0.048557  0.153083 -0.545101 -0.604763 -0.362599
# Na          0.048557  1.000000 -0.201378  0.181751 -0.233588 -0.612858
# Mg          0.153083 -0.201378  1.000000 -0.527254 -0.421251  0.213114
# Al         -0.545101  0.181751 -0.527254  1.000000  0.345778  0.073454
# Si         -0.604763 -0.233588 -0.421251  0.345778  1.000000  0.062254
# K          -0.362599 -0.612858  0.213114  0.073454  0.062254  1.000000
# Ca          0.693527  0.017686 -0.312659 -0.257871 -0.160594 -0.532496
# Ba         -0.220007  0.555664 -0.443013  0.542199  0.176152 -0.294268
# Fe         -0.016099 -0.209057  0.099888 -0.104853  0.018382  0.095794
# Glass_type -0.163160  0.535440 -0.626069  0.610877  0.257640 -0.391378
#
#                   Ca        Ba        Fe  Glass_type
# RI          0.693527 -0.220007 -0.016099   -0.163160
# Na          0.017686  0.555664 -0.209057    0.535440
# ...

# %%
plt.figure(figsize=(20,15))
sns.heatmap(df.corr(),annot=True,linewidths=0.1,linecolor="black",fmt=".1g",cmap="Blues_r")
plt.yticks(rotation=0);
plt.show()

# %%
cor['Glass_type'].sort_values(ascending=False)
# Out:
# Glass_type    1.000000
# Ba            0.710147
# Al            0.610877
# Na            0.535440
# Si            0.257640
# Ca            0.133764
# RI           -0.163160
# Fe           -0.205058
# K            -0.391378
# Mg           -0.626069
# Name: Glass_type, dtype: float64

# %%
plt.figure(figsize=(20,10))
df.corr()['Glass_type'].sort_values(ascending=False).drop(['Glass_type']).plot(kind='bar',color='m')
plt.xlabel('Features',fontsize=15)
plt.ylabel('Labels',fontsize=15)
plt.title('Corealtion between Features and lebels using bar plot',fontsize=20)
plt.show()
