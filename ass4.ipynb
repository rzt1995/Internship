# %%
# !pip install selenium

# %%
import selenium
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException,StaleElementReferenceException
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import requests
import time

# %%
driver= webdriver.Chrome(r"chromedriver.exe")

# %%
driver.get('https://www.amazon.in/')

# %%
search=driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input')
search.send_keys('Guitar')

# %%
button=driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input')
button.click()

# %%
product_url=[]
start=0
end=3
for page in range(start,end):
    
    url=driver.find_elements(By.XPATH,'//a[@class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]')
    for i in url:
        product_url.append(i.get_attribute('href'))
        next_button=driver.find_elements(By.XPATH,'/html/body/div[1]/div[2]/div[1]/div[1]/div/span[1]/div[1]/div[59]/div/div/span/a[3]')

# %%
len(product_url)
# Out:
# 192

# %%
product_url
# Out:
# ['https://www.amazon.in/sspa/click?ie=UTF8&spc=MTo2MTcwOTcwMzIzMDc1NjY6MTY4MTMxOTI5NzpzcF9hdGY6MjAwOTY2MDg3NTA0OTg6OjA6Og&url=%2FKadence-Frontier-Acoustic-Guitar-Strings%2Fdp%2FB01GDZ46AA%2Fref%3Dsr_1_1_sspa%3Fcrid%3DWW3M63UBDZTD%26keywords%3DGuitar%26qid%3D1681319297%26sprefix%3Dguitar%252Caps%252C5334%26sr%3D8-1-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9hdGY%26psc%3D1%26smid%3DAM04Z7MH4HSDD',
#  'https://www.amazon.in/sspa/click?ie=UTF8&spc=MTo2MTcwOTcwMzIzMDc1NjY6MTY4MTMxOTI5NzpzcF9hdGY6MjAwNTcxOTMwNTYyMDQ6OjA6Og&url=%2FKadence-Slowhand-Premium-Acoustic-Instrument%2Fdp%2FB077SZ667X%2Fref%3Dsr_1_2_sspa%3Fcrid%3DWW3M63UBDZTD%26keywords%3DGuitar%26qid%3D1681319297%26sprefix%3Dguitar%252Caps%252C5334%26sr%3D8-2-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9hdGY%26psc%3D1%26smid%3DAM04Z7MH4HSDD',
# ...

# %%
brand_name=[]
name_of_product=[]
price=[]
return_exchange=[]
expected_delivery=[]
availability=[]

# %%
brand_name=[]
for i in product_url:
    driver.get(i)
    time.sleep(5)
    try:
        bname=driver.find_elements(By.XPATH,'//td[@class="a-size-base prodDetAttrValue"]')
        for j in bname:
            
            brand_name.append(j.text)
    except NoSuchElementException :
        brand_name.append('-')

# %%
brand_name
# Out:
# ['Kadence',
#  'Kadence',
#  'FNTR-C',
#  '108.3 x 52.3 x 14.2 cm; 3.85 Kilograms',
#  'FNTR-C',
#  'No',
#  'No',
#  'No',
#  'Kadence',
#  'China',
#  '3 kg 850 g',
#  'B01GDZ46AA',
#  '30 May 2016',
#  'Acoustic Steel-String Guitars',
#  'Kadence',
#  'Kadence',
#  'SH-02-03-04',
#  '108.1 x 52 x 16.2 cm; 4.32 Kilograms',
#  'SH-02-03-04',
#  'No',
#  'No',
#  'Rose Wood',
#  'Right',
#  'Kadence',
#  'China',
#  '4 kg 320 g',
#  'B077SZ667X',
#  '28 November 2017',
#  'Acoustic Steel-String Guitars',
#  'VAULT',
#  'Vault',
#  'EA34NT',
#  'Treveler Acoustic Guitar',
#  '97.5 x 43 x 10.5 cm; 2.38 Kilograms',
#  'EA34NT',
#  'Gig-Bag, Picks, String Set, String Winder, Strap, Polishing Cloth & Ebook',
#  'No',
#  'Bass Wood',
#  'Right',
#  'Vault',
#  'China',
#  '2 kg 380 g',
#  'B07RK9962M',
#  '16 September 2019',
#  'Bajaao Music Pvt Ltd',
#  '97.5 x 43 x 10.5 Centimeters',
#  '9.00 count',
#  'Acoustic Steel-String Guitars',
#  'VAULT',
#  'VAULT',
#  'DA40NT',
#  'DA40NT',
# ...

# %%
len(brand_name)
# Out:
# 3882
